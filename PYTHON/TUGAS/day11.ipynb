# %%
#Menampilkan Drive
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
#import library pandas
import pandas as pd

# %%
#membaca dataset
mydataset = {
    'cars':['bmw','toyota','avanza'],
    'passings':[3,7,4]
}
df = pd.DataFrame(mydataset)
print(df)
# Out:
#      cars  passings
# 0     bmw         3
# 1  toyota         7
# 2  avanza         4

# %% [markdown]
# ## Data CSV

# %%
##read data csv pada drive
df = pd.read_csv('/content/gdrive/MyDrive/Python TIA/ml-1m/data.csv')
print(df.head())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
print(df.loc[17])
# Out:
# Duration     45.0
# Pulse        90.0
# Maxpulse    112.0
# Calories      NaN
# Name: 17, dtype: float64

# %%
#drop Nan
df3 = df.dropna()

# %%
print(df.loc[17])
# Out:
# Duration     45.0
# Pulse        90.0
# Maxpulse    112.0
# Calories      NaN
# Name: 17, dtype: float64

# %%
print(df3.head(20))
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7         45    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# 13        60    104       132     379.3
# 14        60     98       123     275.0
# 15        60     98       120     215.2
# 16        60    100       120     300.0
# 18        60    103       123     323.0
# 19        45     97       125     243.0
# 20        60    108       131     364.2

# %%
df3.reset_index(drop=True,inplace=True )
print(df3.head(20))
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7         45    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# 13        60    104       132     379.3
# 14        60     98       123     275.0
# 15        60     98       120     215.2
# 16        60    100       120     300.0
# 17        60    103       123     323.0
# 18        45     97       125     243.0
# 19        60    108       131     364.2

# %%
##Export ke csv yg baru setelah NaN dihapus
df3.to_csv('data_clean.csv',index=False)

# %%
clean = pd.read_csv('data_clean.csv')
print(clean.head(40))
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7         45    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# 13        60    104       132     379.3
# 14        60     98       123     275.0
# 15        60     98       120     215.2
# 16        60    100       120     300.0
# 17        60    103       123     323.0
# 18        45     97       125     243.0
# 19        60    108       131     364.2
# 20        45    100       119     282.0
# 21        60    130       101     300.0
# ...

# %%
##check duplicate
print(clean.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 159    False
# 160    False
# 161    False
# 162    False
# 163    False
# Length: 164, dtype: bool

# %%
clean.drop_duplicates(inplace=True)

# %%
print(clean.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 159    False
# 160    False
# 161    False
# 162    False
# 163    False
# Length: 157, dtype: bool

# %%
##Convert ketika duplikasi dihapus
clean.to_csv('data_clean1.csv',index=False)

# %%
clean1= pd.read_csv('data_clean1.csv')
print(clean1.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 152    False
# 153    False
# 154    False
# 155    False
# 156    False
# Length: 157, dtype: bool

# %% [markdown]
# ## Latihan indexing

# %%
##series
a=[1,2,3]
myvar = pd.Series(a,index=["Row-1",'Row-2','Row-3'])
print(myvar)
# Out:
# Row-1    1
# Row-2    2
# Row-3    3
# dtype: int64

# %%
calories = {'day1':100,'day2':200,'day3':300}
print(pd.Series(calories))
# Out:
# day1    100
# day2    200
# day3    300
# dtype: int64

# %%
##read excel
df2 = pd.read_excel('/content/gdrive/MyDrive/Python TIA/ml-1m/data1.xlsx')
print(df2.tail())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
#info
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# None
