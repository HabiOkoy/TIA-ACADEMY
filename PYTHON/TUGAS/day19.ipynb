# %% [markdown]
# ### POLYNOMIAL LINIER REGRESSIONS
# y = b0 + b1x1 + b2x2^2 + ... + bnxn^n

# %% [markdown]
# ### import library

# %%
#Menampilkan Drive
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### importing the database

# %%
dataset = pd.read_csv("/content/gdrive/MyDrive/Python TIA/ml-1m/Position_Salaries.csv")
dataset
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %% [markdown]
#     strudi kasus :
# 1.  HRD meminta seorang data science dalam memastikan seorang kadidat
# 2. jabatan nya sebelumnya : Region Manager
# 3. dia meminta gaji 165000 per tahun
# 4. HRD bertanya kepada seorang data science permintaan Region Manager benar apa salah
# 5. jawab dengan model yang bisa memprediksi gaji berdasarkan level jabatannya
# 6.  buat level gaji dengan level 6,5(165000)

# %%
X = dataset.iloc[:,1:-1]    
y = dataset.iloc[:,-1]   
X.shape
# Out:
# (10, 1)

# %%
y.shape
# Out:
# (10,)

# %% [markdown]
# ### Training the linier regression model on the whole dataset
# karena data nya sedikit makanya tidak di split terlebih dahulu, seperti sebelumnya juga untuk mempersingkat waktu pengerjaan

# %%
from sklearn.linear_model import LinearRegression
lin_regr = LinearRegression()
lin_regr.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Training the polynomial regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_regr = PolynomialFeatures(degree=2)
X_poly = poly_regr.fit_transform(X)
lin_regr_2=LinearRegression()
lin_regr_2.fit(X_poly,y)             # .fit() digunakan untuk membuat modelnya
# Out:
# LinearRegression()

# %% [markdown]
# ### Visualising the linier regression result

# %%
# garfik scatter
plt.scatter(X,y,color="blue")
# grafik linier regresi
plt.plot(X,lin_regr.predict(X),color="red")
plt.title("true or bluff (linier regression )")
plt.xlabel("level posision")
plt.ylabel("salary")
plt.show()

# %% [markdown]
# terlihat di garfik di atas dengan Visualising the linier regression result tidak bisa digunakan maka kita pakai visualisasi dengan visualising polinomial regression

# %% [markdown]
# ### Visualising the linier regression result

# %%
# garfik scatter
plt.scatter(X,y,color="blue")
# grafik linier regresi
plt.plot(X,lin_regr_2.predict(X_poly),color="red")
plt.title("true or bluff (linier regression )")
plt.xlabel("level posision")
plt.ylabel("salary")
plt.show()
